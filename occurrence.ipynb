# %% [markdown]
# # The Occurrences of Named Entities: Concept and Workflow
# by Tina Chen & Adam Anderson (PI)
#
#
# ##Concept:
# The concept of citing an occurrence of a source is already well established in scientific publishing. The convention includes a source citation in an accepted format (e.g. MLA format), which provides evidence of the exact reference to the given entity. While this convention has been in place for a number of centuries, there has been no attempt to make this process comprehensive in any way, and most publications only cite the first, latest, or most relevant source on the subject. While this limited approach has been sufficient for human scholarship in the sciences, it does not go far enough to enable automated methods for entity detection in machine learning. This is primarily due to the ambiguity in named entities, as well as the alternative spellings of such entities, as published in the different languages around the world.
# The result of this work will add valuable linked data for machine learning. Once these entities are properly cited, we can include each reference in Linked Data (e.g. Wikidata).
#
# The following workflow establishes a comprehensive method for detecting and disambiguating named entities in a collection of publications, beginning with a batch of 20k. Each occurrence of an entity is counted and given a page number for formal citation purposes. Additional contextualizing methods will be included at a later stage to address any ambiguity in the resulting occurrences of entities.
#
# ##Workflow:
# * Dataset: The first batch included 20k documents.
# * Data Dictionary: 600 Geographic names (GN), both modern and ancient names for each site.
#
# 1. Count the ‘occurrences’ of the GNs in the dataset. (this was done by Circle in GSoC 2022)
# 2. Collect the occurrences into a DataFrame for each GN
# 3. Obtain page numbers for each occurrence
# 4. Make an equivalency to the actual page numbers of the document
# 5. Provide the bibliographic data for each document
# 6. Format with Wikidata properties and item IDs
# 7. Export dataset to Zenodo (CSV, json-ld, BibTex)
# 8. Export dataset to Wikidata using QuickStatements (CSV)

# %%
# !pip3 install geojson
# !pip3 install shapely.constructive
# !pip install geopandas
import pandas as pd
import numpy as np
import csv 
import plotly.express as px
import geopandas as gpd
import json
import requests
# %matplotlib inline
from shapely.geometry import Point
from geopandas import datasets, GeoDataFrame, read_file
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting geojson
#   Downloading geojson-3.0.1-py3-none-any.whl (15 kB)
# Installing collected packages: geojson
# Successfully installed geojson-3.0.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement shapely.constructive (from versions: none)
# ERROR: No matching distribution found for shapely.constructive
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting geopandas
#   Downloading geopandas-0.12.2-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 13.1 MB/s eta 0:00:00
# Collecting pyproj>=2.6.1.post1
#   Downloading pyproj-3.5.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 46.3 MB/s eta 0:00:00
# Requirement already satisfied: shapely>=1.7 in /usr/local/lib/python3.9/dist-packages (from geopandas) (2.0.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from geopandas) (23.0)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from geopandas) (1.4.4)
# Collecting fiona>=1.8
#   Downloading Fiona-1.9.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/16.1 MB 45.2 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.9/dist-packages (from fiona>=1.8->geopandas) (6.1.0)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.9/dist-packages (from fiona>=1.8->geopandas) (22.2.0)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.9/dist-packages (from fiona>=1.8->geopandas) (8.1.3)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.9/dist-packages (from fiona>=1.8->geopandas) (2022.12.7)
# Collecting munch>=2.3.2
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.0->geopandas) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.0->geopandas) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.0->geopandas) (1.22.4)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from munch>=2.3.2->fiona>=1.8->geopandas) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata->fiona>=1.8->geopandas) (3.15.0)
# Installing collected packages: pyproj, munch, cligj, click-plugins, fiona, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.7.2 fiona-1.9.2 geopandas-0.12.2 munch-2.5.0 pyproj-3.5.0

# %%
from google.colab import drive
drive.mount('/content/drive')
#workdir = '/content/drive/MyDrive/Sumerian Network' # for Tina
workdir = '/content/drive/MyDrive/FactGrid Cuneiform (AWCA)/geography/' # for Adam
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### I. LoD Dictionary: FactGrid
# The first step is to load the Linked open Data (LoD) dictionary for the Geographic Names (GN) used to find their occurrences. We are working from the FactGrid dataset because it includes the labels for each GN for both their modern and ancient name, along with links to wikidata.

# %%
factgrid_merge = pd.read_csv("/content/drive/MyDrive/FactGrid Cuneiform (AWCA)/geography/factgrid_merge.csv")
factgrid_merge.head()
# Out:
#    Unnamed: 0.1                                 ancientplace  \
# 0             0  https://database.factgrid.de/entity/Q389901
# 1             1  https://database.factgrid.de/entity/Q389900
# 2             2  https://database.factgrid.de/entity/Q389898
# 3             3  https://database.factgrid.de/entity/Q389892
# 4             4  https://database.factgrid.de/entity/Q389891
#
#                     coord namehistory  cdli2     pleiades  Unnamed: 0  \
# 0  Point(43.2304 35.5931)     تل حويش   95.0          NaN        58.0
# 1    Point(41.166 36.816)    تل حميدي    NaN     874740.0       303.0
# 2  Point(40.0399 36.8268)      تل حلف    NaN     874739.0       289.0
# 3  Point(45.7032 31.8254)      تل جدر  318.0     912957.0       195.0
# 4  Point(40.5872 36.7381)     تل بيدر  260.0  423885388.0       155.0
#
#   Double record?      qid  Sarwiki  ...  \
# 0            NaN  Q389901      NaN  ...
# 1            NaN  Q389900      NaN  ...
# 2            NaN  Q389898      NaN  ...
# 3            NaN  Q389892      NaN  ...
# 4            NaN  Q389891  تل_بيدر  ...
#
#                                     wik_en_y  \
# 0                                        NaN
# 1                                          0
# 2                                        NaN
# 3                                          0
# 4  https://en.wikipedia.org/wiki/Tell_Beydar
#
#                                 wik_ara_y wik_fas_y wik_gre_y wik_heb_y  \
# 0                                     NaN       NaN       NaN       NaN
# 1                                     NaN       NaN       NaN       NaN
# 2                                     NaN       NaN       NaN       NaN
# 3                                     NaN       NaN       NaN       NaN
# 4  https://ar.wikipedia.org//wiki/تل_بيدر       NaN       NaN       NaN
#
#    wik_tr_y                 geometry _merge P402_(Wikidata) P10689_(Wikidata)
# 0       NaN  POINT (43.2305 35.5931)   both             NaN               NaN
# 1       NaN  POINT (41.1661 36.8161)   both     567216082.0              node
# 2       NaN    POINT (40.04 36.8269)   both     573540773.0              node
# 3       NaN  POINT (45.7033 31.8255)   both             NaN               NaN
# 4       NaN  POINT (40.5873 36.7382)   both     226879817.0               way
#
# [5 rows x 93 columns]

# %% [markdown]
# ### II. Occurrence List
# The next step is to obtain the list of documents and their 'occurrences.csv' files which were created by counting the occurnces of each GN in the 20k document dataset (in Google Drive).

# %%
ocurrance_list = pd.read_csv("/content/drive/MyDrive/FactGrid Cuneiform (AWCA)/geography/catalog_1.csv")
ocurrance_list = ocurrance_list.loc[ocurrance_list["filename"] == "occurences.csv"]
ocurrance_list = ocurrance_list.reset_index()
ocurrance_list.reset_index()
# Out:
#        level_0  index                                         ocr-output  \
# 0            0      2  ocr-output/0_Attinger - A propos de AK «faire»...
# 1            1      7  ocr-output/10000_JCS 19, Borger, Aufstieg NB R...
# 2            2     11  ocr-output/10000_JCS 19, Borger, Aufstieg NB R...
# 3            3     15                             ocr-output/10001_Soden
# 4            4     19  ocr-output/10003_Conservation the Core of Arch...
# ...        ...    ...                                                ...
# 20907    20907  83691  ocr-output/9997_Coleman - A History Of Politic...
# 20908    20908  83695      ocr-output/9998_Yun 2008 diss Tell Fekheriyeh
# 20909    20909  83699                            ocr-output/999_41103868
# 20910    20910  83703  ocr-output/99_Fensham--Some Remarks on the Fir...
# 20911    20911  83707  ocr-output/9_van den Hout (2006) - Life and Ti...
#
#              filename
# 0      occurences.csv
# 1      occurences.csv
# 2      occurences.csv
# 3      occurences.csv
# 4      occurences.csv
# ...               ...
# 20907  occurences.csv
# 20908  occurences.csv
# 20909  occurences.csv
# 20910  occurences.csv
# 20911  occurences.csv
#
# [20912 rows x 4 columns]

# %%
# occur1 = pd.read_csv(f"/content/drive/MyDrive/FactGrid Cuneiform (AWCA)/ocr/{ocurrance_list.iloc[0,1]}/{ocurrance_list.iloc[0,2]}")
# occur1["path"] = f"/content/drive/MyDrive/FactGrid Cuneiform (AWCA)/ocr/{ocurrance_list.iloc[0,1]}/page.csv"
# not_exist = pd.read_csv(f'/content/drive/MyDrive/FactGrid Cuneiform (AWCA)/ocr/ocr-output/{name} /{ocurrance_list.iloc[3660,2]}')
# not_exist

# %%
# try:
#   tbl = pd.read_csv(f"/content/drive/MyDrive/FactGrid Cuneiform (AWCA)/ocr/{name}/{ocurrance_list.iloc[0,2]}")
#   tbl["path"] = f"{ocurrance_list.iloc[0,1]}/page.csv"
# except FileNotFoundError:
#   tbl = pd.read_csv(f"/content/drive/MyDrive/FactGrid Cuneiform (AWCA)/ocr/{name} /{ocurrance_list.iloc[0,2]}")
#   tbl["path"] = f"{ocurrance_list.iloc[0,1]} /page.csv"
# tbl

# %%
# occur1 = pd.DataFrame()
# for i in range(len(ocurrance_list)):
#   try:
#     tbl = pd.read_csv(f"/content/drive/MyDrive/FactGrid Cuneiform (AWCA)/ocr/{ocurrance_list.iloc[i,1]}/{ocurrance_list.iloc[i,2]}")
#     tbl["path"] = f"{ocurrance_list.iloc[i,1]}/page.csv"
#   except FileNotFoundError:
#     try:
#       tbl = pd.read_csv(f"/content/drive/MyDrive/FactGrid Cuneiform (AWCA)/ocr/{ocurrance_list.iloc[i,1]} /{ocurrance_list.iloc[i,2]}")
#       tbl["path"] = f"{ocurrance_list.iloc[i,1]} /page.csv"
#     except FileNotFoundError:
#       print(f"{ocurrance_list.iloc[i,0]}/{ocurrance_list.iloc[i,1]}")
#   occur1 = pd.concat([occur1,tbl])

# %%
# occur1.to_csv("/content/drive/MyDrive/FactGrid Cuneiform (AWCA)/geography/occur_sum.csv")

# %%
fact = factgrid_merge[["qid","Len"]]
fact
# Out:
#          qid           Len
# 0    Q389901  Tall Ḥuwaysh
# 1    Q389900   Tall Ḥamīdī
# 2    Q389898        Guzana
# 3    Q389892    Tall Jidar
# 4    Q389891   Tell Beydar
# ..       ...           ...
# 603  Q390009   Kānī Shāyah
# 604  Q390019         Nigūb
# 605  Q390073  Ziyaret Tepe
# 606  Q390044       Kuşaklı
# 607  Q390020        Nimrud
#
# [608 rows x 2 columns]

# %% [markdown]
# ### III. Occurrences Sum
# Here we have a complete list of occurrences, which we can see includes the modern name, ancient name, and even includes null values. So we will remove those instances of 0 occurrence from this dataset, which will leave us with the full dataset of occurrences and along with the documents directory paths and names.

# %%
ocurr_sum = pd.read_csv("/content/drive/MyDrive/FactGrid Cuneiform (AWCA)/geography/occur_sum.csv")
ocurr_sum
# Out:
#          Unnamed: 0   id                           provenience  ancient_name  \
# 0                 0   21               Ur (mod. Tell Muqayyar)            Ur
# 1                 1  149          Me-Turran (mod. Tell Haddad)     Me-Turran
# 2                 2   22                  Nippur (mod. Nuffar)        Nippur
# 3                 3  303                  Isin (mod. Bahriyat)          Isin
# 4                 4  105                     Uruk (mod. Warka)          Uruk
# ...             ...  ...                                   ...           ...
# 7653787         361  137          uncertain (mod. Chogha Mish)     uncertain
# 7653788         362  136          Ašnakkum (mod. Chagar Bazar)      Ašnakkum
# 7653789         363  135  Dur-Katlimmu (mod. Tall Shekh Hamad)  Dur-Katlimmu
# 7653790         364  134             Kar-Nabu (mod. uncertain)      Kar-Nabu
# 7653791         365  637              Guzana (mod. Tell Halaf)        Guzana
#
#               modern_name  total_occurences  \
# 0           Tell Muqayyar                57
# 1             Tell Haddad                21
# 2                  Nuffar                 4
# 3                Bahriyat                 3
# 4                   Warka                 2
# ...                   ...               ...
# 7653787       Chogha Mish                 0
# 7653788      Chagar Bazar                 0
# 7653789  Tall Shekh Hamad                 0
# 7653790         uncertain                 0
# 7653791        Tell Halaf                 0
#
#                                                       path
# 0        ocr-output/0_Attinger - A propos de AK «faire»...
# 1        ocr-output/0_Attinger - A propos de AK «faire»...
# 2        ocr-output/0_Attinger - A propos de AK «faire»...
# 3        ocr-output/0_Attinger - A propos de AK «faire»...
# 4        ocr-output/0_Attinger - A propos de AK «faire»...
# ...                                                    ...
# 7653787  ocr-output/9_van den Hout (2006) - Life and Ti...
# 7653788  ocr-output/9_van den Hout (2006) - Life and Ti...
# 7653789  ocr-output/9_van den Hout (2006) - Life and Ti...
# 7653790  ocr-output/9_van den Hout (2006) - Life and Ti...
# 7653791  ocr-output/9_van den Hout (2006) - Life and Ti...
#
# [7653792 rows x 7 columns]

# %%
# occur1.groupby("path").count()

# %% [markdown]
# ### IV. Modern names
# Here we count the occurrences of the modern names in each of the documents.

# %%
sum_tbl_modern = fact.merge(ocurr_sum, left_on = "Len", right_on = "modern_name")
sum_tbl_modern.sort_values(by = "total_occurences").drop_duplicates()
# Out:
#             qid      Len  Unnamed: 0   id              provenience  \
# 0       Q390165   Ozbaki         204   64  uncertain (mod. Ozbaki)
# 570821  Q390036  Kültepe          17  291    Kanesh (mod. Kültepe)
# 570823  Q390036  Kültepe          30  291    Kanesh (mod. Kültepe)
# 570824  Q390036  Kültepe          22  291    Kanesh (mod. Kültepe)
# 570825  Q390036  Kültepe          24  291    Kanesh (mod. Kültepe)
# ...         ...      ...         ...  ...                      ...
# 277169  Q389820  Babylon           1  200    Bābili (mod. Babylon)
# 616709  Q390059   Harran           0  202     Harran (mod. Harran)
# 278413  Q389820  Babylon           0  200    Bābili (mod. Babylon)
# 567727  Q390036  Kültepe           0  291    Kanesh (mod. Kültepe)
# 304237  Q389820  Babylon           3  200    Bābili (mod. Babylon)
#
#        ancient_name modern_name  total_occurences  \
# 0         uncertain      Ozbaki                 0
# 570821       Kanesh     Kültepe                 0
# 570823       Kanesh     Kültepe                 0
# 570824       Kanesh     Kültepe                 0
# 570825       Kanesh     Kültepe                 0
# ...             ...         ...               ...
# 277169       Bābili     Babylon               846
# 616709       Harran      Harran               888
# 278413       Bābili     Babylon               891
# 567727       Kanesh     Kültepe               891
# 304237       Bābili     Babylon              1282
#
#                                                      path
# 0       ocr-output/0_Attinger - A propos de AK «faire»...
# 570821  ocr-output/16944_Lambert 1985 The pair Lahmu-L...
# 570823  ocr-output/16945_CANE, Green, Iconography/page...
# 570824               ocr-output/16947_0415149282/page.csv
# 570825                     ocr-output/16948_zava/page.csv
# ...                                                   ...
# 277169  ocr-output/1558_Heimpel 2003 Letters to the Ki...
# 616709  ocr-output/26935_CHANE 10 Holloway, Assur is k...
# 278413  ocr-output/17557_Jursa_2010_Aspects_of_the_Eco...
# 567727        ocr-output/12820_JCSSupp4_2014 (5)/page.csv
# 304237  ocr-output/3176_balzer2007_achaimenidischekuns...
#
# [633828 rows x 9 columns]

# %% [markdown]
# ### V. Ancient names
# Here we count the total occurrences of the ancient names as they were identified in each of the documents.

# %%
sum_tbl_modern = sum_tbl_modern.loc[sum_tbl_modern["total_occurences"] != 0]
sum_tbl_modern
# Out:
#             qid      Len  Unnamed: 0   id               provenience  \
# 711     Q390165   Ozbaki          96   64   uncertain (mod. Ozbaki)
# 712     Q390165   Ozbaki          96   64   uncertain (mod. Ozbaki)
# 1852    Q390165   Ozbaki          69   64   uncertain (mod. Ozbaki)
# 1853    Q390165   Ozbaki          69   64   uncertain (mod. Ozbaki)
# 6789    Q390165   Ozbaki          25   64   uncertain (mod. Ozbaki)
# ...         ...      ...         ...  ...                       ...
# 856223  Q390044  Kuşaklı           3  190  uncertain (mod. Kuşaklı)
# 856522  Q390044  Kuşaklı           0  190  uncertain (mod. Kuşaklı)
# 856523  Q390044  Kuşaklı           0  190  uncertain (mod. Kuşaklı)
# 856606  Q390044  Kuşaklı           4  190  uncertain (mod. Kuşaklı)
# 857246  Q390044  Kuşaklı          74  190  uncertain (mod. Kuşaklı)
#
#        ancient_name modern_name  total_occurences  \
# 711       uncertain      Ozbaki                 2
# 712       uncertain      Ozbaki                 2
# 1852      uncertain      Ozbaki                 1
# 1853      uncertain      Ozbaki                 1
# 6789      uncertain      Ozbaki                 1
# ...             ...         ...               ...
# 856223    uncertain     Kuşaklı                 2
# 856522    uncertain     Kuşaklı                 3
# 856523    uncertain     Kuşaklı                 3
# 856606    uncertain     Kuşaklı                 1
# 857246    uncertain     Kuşaklı                 1
#
#                                                      path
# 711                  ocr-output/10641_Ebeling, E/page.csv
# 712                  ocr-output/10641_Ebeling, E/page.csv
# 1852    ocr-output/11693_Mieroop - A History of the An...
# 1853    ocr-output/11693_Mieroop - A History of the An...
# 6789              ocr-output/17974_FrancfMarha-4/page.csv
# ...                                                   ...
# 856223              ocr-output/8944_TAS, KARAKIZ/page.csv
# 856522               ocr-output/9205_Melchert, H/page.csv
# 856523               ocr-output/9205_Melchert, H/page.csv
# 856606               ocr-output/9281_ArAn8-KUB 5/page.csv
# 857246  ocr-output/986_oxford_handbook_cuneiform_cultu...
#
# [38446 rows x 9 columns]

# %%
sum_tbl_ancient = fact.merge(ocurr_sum, left_on = "Len", right_on = "ancient_name")
sum_tbl_ancient.sort_values(by = "total_occurences").drop_duplicates()
# Out:
#             qid     Len  Unnamed: 0   id                  provenience  \
# 0       Q389898  Guzana         365  637     Guzana (mod. Tell Halaf)
# 728921  Q390014    Kish         178  391   Kish (mod. Tell el-Bender)
# 728922  Q390014    Kish         224   85    Kish (mod. Tell Ingharra)
# 728923  Q390014    Kish         319  184     Kish (mod. Tell Uhaimir)
# 728924  Q390014    Kish         117  361  Kish (mod. Tell Barguthiat)
# ...         ...     ...         ...  ...                          ...
# 160183  Q390001   Assur           0  211   Assur (mod. Qalat Sherqat)
# 26054   Q389896    Mari           2  161      Mari (mod. Tell Hariri)
# 150108  Q390001   Assur           0  211   Assur (mod. Qalat Sherqat)
# 172438  Q389938    Ebla           1   79     Ebla (mod. Tell Mardikh)
# 85506   Q389832   Girsu           0   88           Girsu (mod. Tello)
#
#        ancient_name      modern_name  total_occurences  \
# 0            Guzana       Tell Halaf                 0
# 728921         Kish   Tell el-Bender                 0
# 728922         Kish    Tell Ingharra                 0
# 728923         Kish     Tell Uhaimir                 0
# 728924         Kish  Tell Barguthiat                 0
# ...             ...              ...               ...
# 160183        Assur    Qalat Sherqat              2335
# 26054          Mari      Tell Hariri              2494
# 150108        Assur    Qalat Sherqat              2896
# 172438         Ebla     Tell Mardikh              2959
# 85506         Girsu            Tello              8550
#
#                                                      path
# 0       ocr-output/0_Attinger - A propos de AK «faire»...
# 728921  ocr-output/1440_Moor, Johannes C de - The poet...
# 728922  ocr-output/1440_Moor, Johannes C de - The poet...
# 728923  ocr-output/1440_Moor, Johannes C de - The poet...
# 728924  ocr-output/14414_Attinger - La malédiction d'...
# ...                                                   ...
# 160183                     ocr-output/4582_PNA 1/page.csv
# 26054   ocr-output/15347_AfO Register 1974-2004_bea2/p...
# 150108                    ocr-output/13455_PNA 2/page.csv
# 172438  ocr-output/15347_AfO Register 1974-2004_bea2/p...
# 85506   ocr-output/1169_AOAT_345 Huh, Su Kyung - Studi...
#
# [585072 rows x 9 columns]

# %%
factgrid_sum = pd.concat([sum_tbl_ancient, sum_tbl_modern], axis = 0)
factgrid_sum = factgrid_sum.drop_duplicates()
factgrid_sum = factgrid_sum.loc[factgrid_sum["total_occurences"] != 0]
factgrid_sum["Pages"] = ""
factgrid_sum = factgrid_sum.drop_duplicates().reset_index(drop = True)
factgrid_sum
# Out:
#            qid      Len  Unnamed: 0   id               provenience  \
# 0      Q389898   Guzana          19  637  Guzana (mod. Tell Halaf)
# 1      Q389898   Guzana           8  637  Guzana (mod. Tell Halaf)
# 2      Q389898   Guzana           4  637  Guzana (mod. Tell Halaf)
# 3      Q389898   Guzana          25  637  Guzana (mod. Tell Halaf)
# 4      Q389898   Guzana          25  637  Guzana (mod. Tell Halaf)
# ...        ...      ...         ...  ...                       ...
# 67885  Q390044  Kuşaklı           4  190  uncertain (mod. Kuşaklı)
# 67886  Q390044  Kuşaklı           3  190  uncertain (mod. Kuşaklı)
# 67887  Q390044  Kuşaklı           0  190  uncertain (mod. Kuşaklı)
# 67888  Q390044  Kuşaklı           4  190  uncertain (mod. Kuşaklı)
# 67889  Q390044  Kuşaklı          74  190  uncertain (mod. Kuşaklı)
#
#       ancient_name modern_name  total_occurences  \
# 0           Guzana  Tell Halaf                16
# 1           Guzana  Tell Halaf                11
# 2           Guzana  Tell Halaf                24
# 3           Guzana  Tell Halaf                 1
# 4           Guzana  Tell Halaf                10
# ...            ...         ...               ...
# 67885    uncertain     Kuşaklı                 1
# 67886    uncertain     Kuşaklı                 2
# 67887    uncertain     Kuşaklı                 3
# 67888    uncertain     Kuşaklı                 1
# 67889    uncertain     Kuşaklı                 1
#
#                                                     path Pages
# 0            ocr-output/10013_akkermansschwartz/page.csv
# 1      ocr-output/10035_Radner_2014_State_Corresponde...
# 2      ocr-output/10048_SAAS11 = Mattila_2000_Magnate...
# 3            ocr-output/10085_Allred PhD2006_é/page.csv
# 4                        ocr-output/10088_cad_p/page.csv
# ...                                                  ...   ...
# 67885              ocr-output/7644_Kulakoglu, F/page.csv
# 67886              ocr-output/8944_TAS, KARAKIZ/page.csv
# 67887               ocr-output/9205_Melchert, H/page.csv
# 67888               ocr-output/9281_ArAn8-KUB 5/page.csv
# 67889  ocr-output/986_oxford_handbook_cuneiform_cultu...
#
# [67890 rows x 10 columns]

# %% [markdown]
# ### VI. Occurance page count
# Once all the possible names are collected for each toponym along with their occurances in the documents, we can list the page numbers for each occurance.
#
# **Note** that this code cell will take at least 3 hours to complete this task. You may need to allow chrome to run in the background in order for this to work.

# %%
factgrid_sum_with_pages = factgrid_sum.copy()
for j in range(len(factgrid_sum_with_pages)):
  tbl = pd.read_csv( f'/content/drive/MyDrive/FactGrid Cuneiform (AWCA)/ocr/{factgrid_sum_with_pages.iloc[j,8]}'
                    )
  tbl = tbl.dropna()
  result = ''
  try:
    for i in range(len(tbl)):
      a = tbl.iloc[i,:]["text"]
      if factgrid_sum_with_pages.iloc[j,:]["Len"] in a or factgrid_sum_with_pages.iloc[j,:]["ancient_name"] in a or factgrid_sum_with_pages.iloc[j,:]["modern_name"] in a:
        result += f'{str(i)} '
  except TypeError or OSError:
      print(j)
  factgrid_sum_with_pages.loc[j,"Pages"] = result
factgrid_sum_with_pages
# Out:
#            qid      Len  Unnamed: 0   id               provenience  \
# 0      Q389898   Guzana          19  637  Guzana (mod. Tell Halaf)
# 1      Q389898   Guzana           8  637  Guzana (mod. Tell Halaf)
# 2      Q389898   Guzana           4  637  Guzana (mod. Tell Halaf)
# 3      Q389898   Guzana          25  637  Guzana (mod. Tell Halaf)
# 4      Q389898   Guzana          25  637  Guzana (mod. Tell Halaf)
# ...        ...      ...         ...  ...                       ...
# 67885  Q390044  Kuşaklı           4  190  uncertain (mod. Kuşaklı)
# 67886  Q390044  Kuşaklı           3  190  uncertain (mod. Kuşaklı)
# 67887  Q390044  Kuşaklı           0  190  uncertain (mod. Kuşaklı)
# 67888  Q390044  Kuşaklı           4  190  uncertain (mod. Kuşaklı)
# 67889  Q390044  Kuşaklı          74  190  uncertain (mod. Kuşaklı)
#
#       ancient_name modern_name  total_occurences  \
# 0           Guzana  Tell Halaf                16
# 1           Guzana  Tell Halaf                11
# 2           Guzana  Tell Halaf                24
# 3           Guzana  Tell Halaf                 1
# 4           Guzana  Tell Halaf                10
# ...            ...         ...               ...
# 67885    uncertain     Kuşaklı                 1
# 67886    uncertain     Kuşaklı                 2
# 67887    uncertain     Kuşaklı                 3
# 67888    uncertain     Kuşaklı                 1
# 67889    uncertain     Kuşaklı                 1
#
#                                                     path  \
# 0            ocr-output/10013_akkermansschwartz/page.csv
# 1      ocr-output/10035_Radner_2014_State_Corresponde...
# 2      ocr-output/10048_SAAS11 = Mattila_2000_Magnate...
# 3            ocr-output/10085_Allred PhD2006_é/page.csv
# 4                        ocr-output/10088_cad_p/page.csv
# ...                                                  ...
# 67885              ocr-output/7644_Kulakoglu, F/page.csv
# 67886              ocr-output/8944_TAS, KARAKIZ/page.csv
# 67887               ocr-output/9205_Melchert, H/page.csv
# 67888               ocr-output/9281_ArAn8-KUB 5/page.csv
# 67889  ocr-output/986_oxford_handbook_cuneiform_cultu...
#
#                                                    Pages
# 0              4 13 58 66 76 78 196 201 202 213 229 238
# 1
# 2      11 41 65 68 82 89 94 97 98 99 122 131 132 147 ...
# 3
# 4
# ...                                                  ...
# 67885
# 67886
# 67887
# 67888
# 67889
#
# [67890 rows x 10 columns]

# %% [markdown]
# ## VII. Save file as CSV and Pickle
# Lastly, we save the resulting data table as a CSV. We can also make a pickle file for ongoing use so we won't have to run this again (3 hours).

# %%
factgrid_sum_with_pages.to_csv('/content/drive/MyDrive/FactGrid Cuneiform (AWCA)/geography/occurance_pagecount.csv')
factgrid_sum_with_pages.to_pickle('/content/drive/MyDrive/FactGrid Cuneiform (AWCA)/geography/occurance_pagecount.p')

# %%
# j = 2
# tbl = pd.read_csv( f'/content/drive/MyDrive/FactGrid Cuneiform (AWCA)/ocr/{factgrid_sum_with_pages.iloc[j,8]}'
#                     )
# result = ''
# for i in range(len(tbl)):
#   try:
#     a = tbl.iloc[i,:]["text"]
#     if factgrid_sum_with_pages.iloc[j,:]["Len"] in a or factgrid_sum_with_pages.iloc[j,:]["ancient_name"] in a or factgrid_sum_with_pages.iloc[j,:]["modern_name"] in a:
#       result += f'{str(i)} '
#   except TypeError:
#       print(j,a)
# factgrid_sum_with_pages.loc[j,"Pages"] = result
# factgrid_sum_with_pages
